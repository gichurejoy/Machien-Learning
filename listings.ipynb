# %% [markdown]
# <a href="https://colab.research.google.com/github/gichurejoy/Machine-Learning/blob/main/listings.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
listings = pd.read_csv("Listings.csv", encoding="ISO-8859-1",low_memory=False, )

# %%
listings.head()
# Out:
#    listing_id                                              name   host_id  \
# 0      281420    Beautiful Flat in le Village Montmartre, Paris   1466919
# 1     3705183                   39 mÃÂ² Paris (Sacre CÃ
# âur)  10328771
# 2     4082273               Lovely apartment with Terrace, 60m2  19252768
# 3     4797344               Cosy studio (close to Eiffel tower)  10668311
# 4     4823489  Close to Eiffel Tower - Beautiful flat : 2 rooms  24837558
#
#    host_since                 host_location host_response_time  \
# 0  03/12/2011  Paris, Ile-de-France, France                NaN
# 1  29/11/2013  Paris, Ile-de-France, France                NaN
# 2  31/07/2014  Paris, Ile-de-France, France                NaN
# 3  17/12/2013  Paris, Ile-de-France, France                NaN
# 4  14/12/2014  Paris, Ile-de-France, France                NaN
#
#    host_response_rate  host_acceptance_rate host_is_superhost  \
# 0                 NaN                   NaN                 f
# ...

# %%
listings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 107626 entries, 0 to 107625
# Data columns (total 33 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   listing_id                   107626 non-null  int64
#  1   name                         107551 non-null  object
#  2   host_id                      107626 non-null  int64
#  3   host_since                   107561 non-null  object
#  4   host_location                107306 non-null  object
#  5   host_response_time           61450 non-null   object
#  6   host_response_rate           61450 non-null   float64
#  7   host_acceptance_rate         66615 non-null   float64
#  8   host_is_superhost            107561 non-null  object
#  9   host_total_listings_count    107561 non-null  float64
#  10  host_has_profile_pic         107561 non-null  object
#  11  host_identity_verified       107561 non-null  object
# ...

# %%
listings["host_since"]=pd.to_datetime(listings["host_since"])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-25-898f77707fc6> in <cell line: 1>()
# ----> 1 listings["host_since"]=pd.to_datetime(listings["host_since"])
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/tools/datetimes.py in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1048             result = arg.map(cache_array)
#    1049         else:
# -> 1050             values = convert_listlike(arg._values, format)
#    1051             result = arg._constructor(values, index=arg.index, name=arg.name)
#    1052     elif isinstance(arg, (ABCDataFrame, abc.MutableMapping)):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/tools/datetimes.py in _convert_listlike_datetimes(arg, format, name, utc, unit, errors, dayfirst, yearfirst, exact)
# ...

# %%
listings.info()

# %%
paris_listings=listings.query("city=='Paris'")
paris_listings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 32077 entries, 0 to 107525
# Data columns (total 33 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   listing_id                   32077 non-null  int64
#  1   name                         32040 non-null  object
#  2   host_id                      32077 non-null  int64
#  3   host_since                   32060 non-null  object
#  4   host_location                32000 non-null  object
#  5   host_response_time           11641 non-null  object
#  6   host_response_rate           11641 non-null  float64
#  7   host_acceptance_rate         15483 non-null  float64
#  8   host_is_superhost            32060 non-null  object
#  9   host_total_listings_count    32060 non-null  float64
#  10  host_has_profile_pic         32060 non-null  object
#  11  host_identity_verified       32060 non-null  object
#  12  neighbourhood                32077 non-null  object
# ...

# %%
paris_listings = (listings.query("city=='Paris'")
.loc[:,["host_since", "neighbourhood", "city","accommodates","price"]])

paris_listings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 32077 entries, 0 to 107525
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   host_since     32060 non-null  object
#  1   neighbourhood  32077 non-null  object
#  2   city           32077 non-null  object
#  3   accommodates   32077 non-null  float64
#  4   price          32077 non-null  float64
# dtypes: float64(2), object(3)
# memory usage: 1.5+ MB

# %%
paris_listings.isna().sum()
# Out:
# host_since       17
# neighbourhood     0
# city              0
# accommodates      0
# price             0
# dtype: int64

# %%
paris_listings.describe()
# Out:
#        accommodates         price
# count  32077.000000  32077.000000
# mean       3.280668    118.062038
# std        1.671730    220.702174
# min        0.000000      0.000000
# 25%        2.000000     60.000000
# 50%        3.000000     85.000000
# 75%        4.000000    120.000000
# max       16.000000  12000.000000

# %%
paris_listings.query("accommodates == 0")#.count()
# Out:
#        host_since neighbourhood   city  accommodates  price
# 98209  20/07/2020      Pantheon  Paris           0.0    0.0

# %%
paris_listings_neighbourhood=(
    paris_listings
    .groupby("neighbourhood")
    .agg({"price":"mean"})
    .sort_values("price")
)
paris_listings_neighbourhood.tail()
# Out:
#                     price
# neighbourhood
# Bourse         156.531301
# Luxembourg     158.861376
# Passy          162.631172
# Louvre         187.516949
# Elysee         204.548998

# %%
paris_listings_accommodates=(
    paris_listings
    .query("neighbourhood=='Elysee'")
    .groupby("accommodates")
    .agg({"price":"mean"})
    .sort_values("price")
)
paris_listings_accommodates.tail()
# Out:
#                    price
# accommodates
# 10.0          558.916667
# 11.0          715.666667
# 16.0          800.000000
# 13.0          842.500000
# 14.0          971.000000

# %%
listings["host_since"] = pd.to_datetime(listings["host_since"], format="%d/%m/%Y")
