# %% [markdown]
# <a href="https://colab.research.google.com/github/gichurejoy/Machine-Learning/blob/main/lab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install gradio -q
# !pip install sentence-transformers -q
# !pip install nltk -q

import nltk
nltk.download('stopwords')
nltk.download('punkt')
# Out:
#      |████████████████████████████████| 11.6 MB 8.5 MB/s
#      |████████████████████████████████| 106 kB 63.0 MB/s
#      |████████████████████████████████| 213 kB 51.4 MB/s
#      |████████████████████████████████| 84 kB 3.5 MB/s
#      |████████████████████████████████| 2.3 MB 48.8 MB/s
#      |████████████████████████████████| 84 kB 3.6 MB/s
#      |████████████████████████████████| 272 kB 41.5 MB/s
#      |████████████████████████████████| 54 kB 2.9 MB/s
#      |████████████████████████████████| 55 kB 3.4 MB/s
#      |████████████████████████████████| 56 kB 3.7 MB/s
#      |████████████████████████████████| 63 kB 1.9 MB/s
#      |████████████████████████████████| 80 kB 8.1 MB/s
#      |████████████████████████████████| 68 kB 4.1 MB/s
#      |████████████████████████████████| 46 kB 2.9 MB/s
#      |████████████████████████████████| 856 kB 35.6 MB/s
#      |████████████████████████████████| 593 kB 38.3 MB/s
#      |████████████████████████████████| 4.1 MB 44.6 MB/s
#   Building wheel for ffmpy (setup.py) ... done
#   Building wheel for python-multipart (setup.py) ... done
#      |████████████████████████████████| 85 kB 3.2 MB/s
#      |████████████████████████████████| 5.5 MB 46.7 MB/s
#      |████████████████████████████████| 1.3 MB 56.3 MB/s
#      |████████████████████████████████| 163 kB 48.7 MB/s
#      |████████████████████████████████| 7.6 MB 49.8 MB/s
#   Building wheel for sentence-transformers (setup.py) ... done
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
from nltk.corpus import stopwords
from sklearn.metrics.pairwise import cosine_similarity
from sentence_transformers import SentenceTransformer

import warnings
warnings.filterwarnings('ignore')

stop = stopwords.words('english')
print(len(stop))
# Out:
# 179

# %%
df = pd.read_csv('titles.csv')
df.sample(10)
# Out:
#                                                    title
# 91181            Kill-safe synchronization abstractions.
# 59734  Sparse Greedy Matrix Approximation for Machine...
# 1135           Ontologies and Representations of Matter.
# 54020      An Online Approach to Physical Design Tuning.
# 42751  Location-Based Software Modeling and Analysis:...
# 87674  The Complexity of Model Checking Higher Order ...
# 83265  Videoviews: A Content Based Video Description ...
# 73489  Enhancing ZigBee throughput under WiFi interfe...
# 67133                              Finding Unusual Code.
# 51505  Object Recognition in High Clutter Images Usin...

# %%
sample = df.sample(50)
sample.head()
# Out:
#                                                    title
# 67764  Extracting Propositional Rules from Feed-forwa...
# 56166  Efficient Versioning for Scientific Array Data...
# 77427  On distinguishing the multiple radio paths in ...
# 56903  Revision provenance in text documents of async...
# 37871  Gesture + Play Exploring Full-Body Navigation ...

# %%
sample = sample.reset_index(drop = True)
sample.head()
# Out:
#                                                title
# 0  Extracting Propositional Rules from Feed-forwa...
# 1  Efficient Versioning for Scientific Array Data...
# 2  On distinguishing the multiple radio paths in ...
# 3  Revision provenance in text documents of async...
# 4  Gesture + Play Exploring Full-Body Navigation ...

# %%
# cleaning
sample['ctitle'] = sample['title'].str.replace('[^\w\s]', '')
sample['ctitle'] = sample['ctitle'].str.replace('\d+', '')
sample['ctitle'] = sample['ctitle'].str.lower()

sample['ctitle'] = sample['ctitle'].apply(lambda item: " ".join(item for item in item.split() if item not in stop))
sample.head()
# Out:
#                                                title  \
# 0  Extracting Propositional Rules from Feed-forwa...
# 1  Efficient Versioning for Scientific Array Data...
# 2  On distinguishing the multiple radio paths in ...
# 3  Revision provenance in text documents of async...
# 4  Gesture + Play Exploring Full-Body Navigation ...
#
#                                               ctitle
# 0  extracting propositional rules feedforward neu...
# 1    efficient versioning scientific array databases
# 2  distinguishing multiple radio paths rssbased r...
# 3  revision provenance text documents asynchronou...
# 4  gesture play exploring fullbody navigation vir...

# %%
#### Feature extraction

model = SentenceTransformer('distilbert-base-nli-mean-tokens')
# Out:
# Downloading:   0%|          | 0.00/690 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/3.99k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/550 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/122 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/265M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/466k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/450 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/229 [00:00<?, ?B/s]

# %%
features = model.encode(sample['title'])
sample['features'] = list(features)
sample.head()
# Out:
#                                                title  \
# 0  Extracting Propositional Rules from Feed-forwa...
# 1  Efficient Versioning for Scientific Array Data...
# 2  On distinguishing the multiple radio paths in ...
# 3  Revision provenance in text documents of async...
# 4  Gesture + Play Exploring Full-Body Navigation ...
#
#                                               ctitle  \
# 0  extracting propositional rules feedforward neu...
# 1    efficient versioning scientific array databases
# 2  distinguishing multiple radio paths rssbased r...
# 3  revision provenance text documents asynchronou...
# 4  gesture play exploring fullbody navigation vir...
#
#                                             features
# 0  [-0.8616396, -0.046837952, 0.92807496, -1.1946...
# 1  [-1.2171917, -0.6645705, 1.0169132, -0.0546872...
# 2  [-0.080526784, -0.37063682, -0.13515614, 0.480...
# 3  [-0.9112716, -0.5371235, 0.09107123, -0.142865...
# 4  [-1.4183482, -0.13093716, 1.1072824, -0.489649...

# %%
print(sample['title'].iloc[46])
print(sample['features'].iloc[46].shape)
#print(sample['features'].iloc[0])
# Out:
# Protecting the web: phishing, malware, and other security threats.
# (768,)

# %%
sample_query = sample.iloc[0]['title']
sample_query
# Out:
# 'Extracting Propositional Rules from Feed-forward Neural Networks - A New Decompositional Approach.'

# %%
query_feature = model.encode([sample_query])

# %%
sample['sim'] = sample['features'].apply(lambda x: cosine_similarity([x], query_feature)[0][0])
sample.head()
# Out:
#                                                title  \
# 0  Extracting Propositional Rules from Feed-forwa...
# 1  Efficient Versioning for Scientific Array Data...
# 2  On distinguishing the multiple radio paths in ...
# 3  Revision provenance in text documents of async...
# 4  Gesture + Play Exploring Full-Body Navigation ...
#
#                                               ctitle  \
# 0  extracting propositional rules feedforward neu...
# 1    efficient versioning scientific array databases
# 2  distinguishing multiple radio paths rssbased r...
# 3  revision provenance text documents asynchronou...
# 4  gesture play exploring fullbody navigation vir...
#
#                                             features       sim
# 0  [-0.8616396, -0.046837952, 0.92807496, -1.1946...  1.000000
# 1  [-1.2171917, -0.6645705, 1.0169132, -0.0546872...  0.481643
# 2  [-0.080526784, -0.37063682, -0.13515614, 0.480...  0.518808
# 3  [-0.9112716, -0.5371235, 0.09107123, -0.142865...  0.655813
# 4  [-1.4183482, -0.13093716, 1.1072824, -0.489649...  0.588319

# %%
sorted_sample = sample.sort_values(by='sim', ascending=False)
sorted_sample.tail()
# Out:
#                                                 title  \
# 5     Exchange of Indivisible Objects with Asymmetry.
# 43  Noise can help: accurate and efficient per-flo...
# 24                Maintaining Near-Popular Matchings.
# 19  Backyard Cuckoo Hashing: Constant Worst-Case O...
# 9          Invisible Safety of Distributed Protocols.
#
#                                                ctitle  \
# 5              exchange indivisible objects asymmetry
# 43  noise help accurate efficient perflow latency ...
# 24                  maintaining nearpopular matchings
# 19  backyard cuckoo hashing constant worstcase ope...
# 9              invisible safety distributed protocols
#
#                                              features       sim
# 5   [-0.85856646, -0.26119414, 0.32830712, 0.55337...  0.415924
# 43  [-0.7408508, -0.4951424, 0.0818987, 0.6860947,...  0.338702
# 24  [-0.69735366, -0.23976684, 0.78036654, -0.1206...  0.312310
# 19  [-1.0591152, -0.366785, 0.074258566, -0.209028...  0.271805
# 9   [-0.8192909, 0.12419824, -0.2592788, 0.2022687...  0.248151

# %%
def return_sim(query):
    query_feature = model.encode([query])
    sample['sim'] = sample['features'].apply(lambda x: cosine_similarity([x], query_feature)[0][0])
    sorted_sample = sample.sort_values(by='sim', ascending=False)
    result = sorted_sample['title'].head(10)
    return list(result)

# %%
x=str(input("Enter a query: "))
print(return_sim(x))
# Out:
# Enter a query: swahili
# ['Summarizing the differences from microblogs.', 'Exchange of Indivisible Objects with Asymmetry.', 'Identifying entity aspects in microblog posts.', 'Strong Bounds for Evolution in Networks.', 'Exploring Opportunities to Facilitate Serendipity in Search.', 'Specification of Mixed Systems in KORRIGAN with the Support of a UML-Inspired Graphical Notation.', 'Learning to advertise.', 'Understanding Execution Traces Using Massive Sequence and Circular Bundle Views.', 'Revision provenance in text documents of asynchronous collaboration.', 'On distinguishing the multiple radio paths in RSS-based ranging.']

# %%
import gradio as gr
iface=gr.Interface(fn=return_sim,inputs="text",outputs="text")
iface.launch(share=True)
# Out:
# Colab notebook detected. To show errors in colab notebook, set `debug=True` in `launch()`
# Running on public URL: https://7d0ecd1f9c5ce07d.gradio.app
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades (NEW!), check out Spaces: https://huggingface.co/spaces
# <div><iframe src="https://7d0ecd1f9c5ce07d.gradio.app" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# (<gradio.routes.App at 0x7f1e6f587950>,
#  'http://127.0.0.1:7861/',
#  'https://7d0ecd1f9c5ce07d.gradio.app')
